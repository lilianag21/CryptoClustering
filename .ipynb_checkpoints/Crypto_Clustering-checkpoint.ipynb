# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e0312d74-f1a5-446a-9b1c-295b3a98dc2a'>
#   <div id="fe0f15fe-b1c0-494f-af57-4fc1664099a7" data-root-id="e0312d74-f1a5-446a-9b1c-295b3a98dc2a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file

crypto_features = df_market_data[[
    "price_change_percentage_24h", 
    "price_change_percentage_7d",
    "price_change_percentage_14d",
    "price_change_percentage_30d",
    "price_change_percentage_60d",
    "price_change_percentage_200d",
    "price_change_percentage_1y"
]]


scaler = StandardScaler()
crypto_scaled = scaler.fit_transform(crypto_features)

# %%
# Create a DataFrame with the scaled data

crypto_scaled_df = pd.DataFrame(
    crypto_scaled, 
    columns = crypto_features.columns,
    index = crypto_features.index
)

# Display the scaled DataFrame

crypto_scaled_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11

k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values

inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_scaled`
# 3. Append the model.inertia_ to the inertia list

for i in k:
    model = KMeans(n_clusters=i, random_state=0)
    model.fit(crypto_scaled_df)
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve

elbow_data_crypto = {
    "k": k,
    "inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve

df_elbow_crypto = pd.DataFrame(elbow_data_crypto)
df_elbow_crypto.head()
# Out:
#    k     inertia
# 0  1  287.000000
# 1  2  198.571818
# 2  3  145.635748
# 3  4   79.022435
# 4  5   66.217780

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.


elbow_plot_crypto = df_elbow_crypto.hvplot.line(x="k", y="inertia", title="Elbow Curve Using Crypto Data", xticks=k)
elbow_plot_crypto
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** The best value for k is 3.

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k

best_k = 3
kmeans_model = KMeans(n_clusters=best_k, random_state=1)

# %%
# Fit the K-Means model using the scaled DataFrame

kmeans_model.fit(crypto_scaled)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame

crypto_scaled_clusters = kmeans_model.predict(crypto_scaled_df)

# Print the resulting array of cluster values.

print(crypto_scaled_clusters)
# Out:
# [2 2 0 0 2 2 2 2 2 0 0 0 0 2 0 2 0 0 2 0 0 2 0 0 0 0 0 0 2 0 0 0 0 2 0 0 1
#  0 0 0 0]
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but KMeans was fitted without feature names
#   warnings.warn(

# %%
# Create a copy of the scaled DataFrame

crypto_scaled_predictions = crypto_scaled_df.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters

crypto_scaled_predictions["CryptoCluster"] = crypto_scaled_clusters

# Display the copy of the scaled DataFrame


crypto_scaled_predictions.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.


crypto_scaled_predictions.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="CryptoCluster",
    hover_cols=["coin_id"],
    title = "Scatter Plot by Cryptocurrencies"
)
# Out:
# :NdOverlay   [CryptoCluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.

pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.

crypto_pca = pca.fit_transform(crypto_scaled_predictions)

pca_columns = ["PC1", "PC2", "PC3"]
crypto_pca_df = pd.DataFrame(crypto_pca, columns=pca_columns, index=crypto_scaled_df.index)

# View the scaled PCA data

crypto_pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin       1.539891  0.001721  0.599430
# ethereum      1.264310 -0.020396  1.158286
# tether       -0.311943 -0.556328 -0.793148
# ripple       -0.308756 -0.607236 -0.643243
# bitcoin-cash  2.972567  0.118691  1.287400

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.

explained_var = pca.explained_variance_ratio_
explained_var

total_var = explained_var.sum()
total_var
# Out:
# 0.8847090109933673

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** The total explained variance is 1.0

# %%
# Create a new DataFrame with the PCA data.

pca_columns = ["PC1", "PC2", "PC3"]
new_crypto_pca_df = pd.DataFrame(crypto_pca, columns=pca_columns)

# Copy the crypto names from the original scaled DataFrame
new_crypto_pca_df["coin_id"] = crypto_scaled_df.index

# Set the coin_id column as index
new_crypto_pca_df = new_crypto_pca_df.set_index("coin_id")

# Display the scaled PCA DataFrame
new_crypto_pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin       1.539891  0.001721  0.599430
# ethereum      1.264310 -0.020396  1.158286
# tether       -0.311943 -0.556328 -0.793148
# ripple       -0.308756 -0.607236 -0.643243
# bitcoin-cash  2.972567  0.118691  1.287400

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11

k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values

inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list

for i in k:
    model = KMeans(n_clusters=i, random_state=0)
    model.fit(new_crypto_pca_df)
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve

elbow_data_pca = {
    "k": k,
    "inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve

df_elbow_pca = pd.DataFrame(elbow_data_pca)
df_elbow_pca.head()
# Out:
#    k     inertia
# 0  1  285.070506
# 1  2  196.623812
# 2  3  112.310737
# 3  4   43.556391
# 4  5   34.258018

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.

elbow_plot_crypto_pca = df_elbow_pca.hvplot.line(x="k", y="inertia", title="Elbow Curve Using Crypto PCA Data", xticks=k)
elbow_plot_crypto_pca
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** The best k value when using PCA data is 2.
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** Yes, the best k value using the original data was 3.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k

best_k = 2
kmeans_model = KMeans(n_clusters=best_k, random_state=1)

# %%
# Fit the K-Means model using the PCA data

kmeans_model.fit(crypto_pca)
# Out:
# KMeans(n_clusters=2, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame

crypto_pca_clusters = model.predict(new_crypto_pca_df)

# Print the resulting array of cluster values.

print(crypto_pca_clusters)
# Out:
# [ 7  1  4  4  7  7  1  1  1  9  0  4  4  7  9  1  0  9  1  4  0  7  0  4
#  10  4  9  5  1  6  9  9  2  1  8 10  3  5  9  4  4]

# %%
# Create a copy of the scaled PCA DataFrame

crypto_pca_predictions = new_crypto_pca_df.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters

crypto_pca_predictions["CryptoCluster"] = crypto_pca_clusters

# Display the copy of the scaled PCA DataFrame

crypto_pca_predictions.head()
# Out:
#                    PC1       PC2       PC3  CryptoCluster
# coin_id
# bitcoin       1.539891  0.001721  0.599430              7
# ethereum      1.264310 -0.020396  1.158286              1
# tether       -0.311943 -0.556328 -0.793148              4
# ripple       -0.308756 -0.607236 -0.643243              4
# bitcoin-cash  2.972567  0.118691  1.287400              7

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.

crypto_pca_predictions.hvplot.scatter(
    x="PC1",
    y="PC2",
    by="CryptoCluster",
    hover_cols=["coin_id"],
    title = "Scatter Plot by Cryptocurrency PCA"
)
# Out:
# :NdOverlay   [CryptoCluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves

df_elbow_crypto['Type'] = 'Original'
df_elbow_pca['Type'] = 'PCA'

df_elbow_all = pd.concat([df_elbow_crypto, df_elbow_pca])

df_elbow_all.hvplot.line(
    x='k', y='inertia', by='Type',
    title='Elbow Curve Comparison',
    xticks=list(range(1, 12))
)
# Out:
# :NdOverlay   [Type]
#    :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters

original_plot = crypto_scaled_predictions.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="CryptoCluster",
    title="Original",
    height=400,
    width=500
)

pca_plot = crypto_pca_predictions.hvplot.scatter(
    x="PC1",
    y="PC2",
    by="CryptoCluster",
    title="PCA",
    height=400,
    width=500
)

original_plot + pca_plot
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [CryptoCluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d)
#    .NdOverlay.II :NdOverlay   [CryptoCluster]
#       :Scatter   [PC1]   (PC2)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** With PCA in place, it is easier to read the plots as the data is focused on the most impactful components. This demonstrates how efficiency is crucial when visualizing data and making observations. At the same time, it can also exclude data points that might influence how we interpret the data, which also uncovers a trade-off  between having too much or too little data.
